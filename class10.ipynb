# %%
x="Hello everyone lets learn python"
l1=x.split(" ")
l1.sort(reverse=True)
print(l1)
print(" ".join(l1))
# Out:
# ['python', 'lets', 'learn', 'everyone', 'Hello']
# python lets learn everyone Hello
# Hello everyone lets learn python

# %%
x="Hello everyone lets learn python"
print(x[::-1]cpa)
# Out:
# nohtyp nrael stel enoyreve olleH

# %%
email="abhijeetbaghel77@gamil.com"
if email.find("@")<email.find("."):
    print("valid hai...")
else:
    print("invalid h..")
# Out:
# valid hai...
